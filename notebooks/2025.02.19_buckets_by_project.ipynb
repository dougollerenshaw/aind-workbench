# %% [markdown]
# # Records by Project and Bucket Analysis
# This notebook analyzes the distribution of records across different projects and storage buckets.
#
# We'll use the AIND Document Database to:
# * Count records per project and bucket combination
# * Display results in a clear tabular format

# %% [markdown]
# ## Imports

# %%
from aind_data_access_api.document_db import MetadataDbClient
import pandas as pd

# Configure pandas to display all columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Connect to the metadata database

# %%
# Initialize the client
client = MetadataDbClient(
    host="api.allenneuraldynamics.org",
    database="metadata_index",
    collection="data_assets",
)

# %% [markdown]
# ## Define a pipeline to retrieve the project and bucket from the location field and execute it

# %%
# Simpler pipeline that only returns project and bucket
pipeline = [
    {
        '$project': {
            'project': '$data_description.project_name',
            'bucket': {'$arrayElemAt': [{'$split': ['$location', '/']}, 2]},
            '_id': 0
        }
    }
]

# Execute the aggregation
results = client.aggregate_docdb_records(pipeline=pipeline)

# %% [markdown]
# ## Convert the results to a pandas dataframe, do some grouping and sorting

# %%
# Convert to DataFrame
df = pd.DataFrame(results)

# Create a grouped count with hierarchical index
grouped_df = df.groupby(['bucket', 'project']).size().reset_index(name='count')

# Convert to hierarchical index
hierarchical_df = grouped_df.set_index(['bucket', 'project'])

# Sort within each bucket by count (descending)
hierarchical_df = hierarchical_df.groupby('bucket', group_keys=False).apply(lambda x: x.sort_values('count', ascending=False))

# Calculate bucket totals
bucket_totals = hierarchical_df.groupby('bucket')['count'].sum()

display(hierarchical_df)
# Out:
#                                                                                             count
# bucket                                  project
# aind-ephys-data                         Dynamic Routing                                       117
#                                         Discovery-Neuromodulator circuit dynamics durin...     95
#                                         Ephys Platform                                         94
#                                         Cell Type Lookup Table                                 87
#                                         Cell Type LUT                                          24
#                                         MRI-Guided Electrophysiology                            4
#                                         Thalamus in the middle                                  3
#                                         MRI-Guided Elecrophysiology                             2
# aind-open-data                          Thalamus in the middle                                349
#                                         MSMA Platform                                         193
#                                         CTY Genetic Tools                                     106
#                                         Cell Type Lookup Table                                 93
#                                         Ophys Platform - FIP, HSFP and indicator testing       52
#                                         Genetic Perturbation Platform                          51
#                                         Ephys Platform                                         34
#                                         MRI-Guided Electrophysiology                           32
#                                         U19 Thalamus in the Middle                             30
#                                         Cell Type LUT                                          27
#                                         Behavior Platform                                      27
#                                         Discovery-Brain Wide Circuit Dynamics                  24
#                                         MGT                                                    22
#                                         CTY Program Admin                                      21
#                                         Dynamic Routing                                        18
#                                         Discovery-Neuromodulator circuit dynamics durin...     12
#                                         - CTY Genetic Tools                                     7
#                                         Thalamus in the middle - Project 6 Molecular Sc...      6
#                                         102-01-064-10 - CTY Genetic Tools                       6
#                                         MRI-Guided Elecrophysiology                             6
#                                         Brain Computer Interface                                5
#                                         Thalamus in the middle - Project 1 Mesoscale th...      5
#                                         AIND Thalamus U19 - Project 2                           5
#                                         AIND Scientific Activities - Molecular and proj         4
#                                         HIVE                                                    4
#                                         AIND Scientific Activities - Ephys Platform             3
#                                         NP Ultra                                                3
#                                         Thalamus in the middle - Project 2 Cell-type sp...      2
#                                         Ophys platform - FIP, HSFP and indicator testing        2
#                                         - CTY GenTools Mouse                                    2
#                                         AIND Scientific Activities - Ophys indicator te...      2
#                                         Costa Greene Adrenal                                    2
#                                         AIND Thalamus U19 - Project 4                           2
#                                         BG AAV Toolbox                                          2
#                                         Learning mFISH-V1omFISH                                 1
#                                         Genetic Perturbation Platform - Subproject 2 Ge...      1
#                                         Ephys platform                                          1
#                                         AIND Thalamus U19 - Project 1                           1
# aind-ophys-data                         Brain Computer Interface                                2
# aind-private-data-prod-o5171v           Dynamic Routing                                      8641
#                                         Behavior Platform                                    3709
#                                         Cognitive flexibility in patch foraging              1330
#                                         Discovery-Neuromodulator circuit dynamics durin...   1227
#                                         Brain Computer Interface                              908
#                                         Ephys Platform                                        568
#                                         Learning mFISH-V1omFISH                               224
#                                         Cell Type LUT                                         141
#                                         Cell Type Lookup Table                                137
#                                         GPP                                                   105
#                                         OpenScope                                              95
#                                         Multiplexed Neuromodulation                            63
#                                         Standalone                                             16
#                                         Behavior and Motor Control                             15
#                                         MRI-Guided Electrophysiology                           14
#                                         NeuropixelsUltra_Psychedelics                          11
#                                         Thalamus in the middle project 4                       11
#                                         Discovery-Neuromodulator circuit dynamics durin...      7
#                                         Thalamus in the middle - Project 4 Frontal cort...      3
#                                         Discoovery-Neuromodulation                              1
#                                         Discovery-Neuromodulation                               1
#                                         Neuropixels Ultra & Psychedelics                        1
# codeocean-s3datasetsbucket-1u41qdg42ur9 Behavior Platform                                    1041
#                                         Discovery-Neuromodulator circuit dynamics durin...    177
#                                         Cell Type Lookup Table                                158
#                                         Learning mFISH-V1omFISH                                69
#                                         Dynamic Routing                                        56
#                                         Ephys Platform                                         49
#                                         GPP                                                    44
#                                         OpenScope                                              29
#                                         Discovery-Neuromodulator circuit dynamics durin...     20
#                                         Cell Type LUT                                          18
#                                         MRI-Guided Electrophysiology                           15
#                                         Thalamus in the middle project 4                       14
#                                         Discoovery-Neuromodulation                              3
#                                         Thalamus in the middle - Project 4 Frontal cort...      3
#                                         MSMA Platform                                           2
#                                         MRI-Guided Elecrophysiology                             1

# %% [markdown]
# ## make a nice markdown table to paste into a github comment

# %%
# Calculate bucket totals and sort buckets by size
bucket_totals = hierarchical_df.groupby('bucket')['count'].sum().sort_values(ascending=False)

# For each bucket, create and print a separate table
for bucket in bucket_totals.index:
    # Get the data for this bucket
    bucket_data = hierarchical_df.loc[bucket].sort_values('count', ascending=False)
    
    # Reset index to make the project name a column
    bucket_data = bucket_data.reset_index()
    
    # Print bucket header with total
    print(f"## {bucket}: {bucket_totals[bucket]:,} records\n")
    
    # Convert to markdown and print
    print(bucket_data.to_markdown(index=False))
    print("\n")  # Add extra newline between tables
# Out:
# ## aind-private-data-prod-o5171v: 17,228 records
#
# | project                                                                                                                                  |   count |
# |:-----------------------------------------------------------------------------------------------------------------------------------------|--------:|
# | Dynamic Routing                                                                                                                          |    8641 |
# | Behavior Platform                                                                                                                        |    3709 |
# | Cognitive flexibility in patch foraging                                                                                                  |    1330 |
# | Discovery-Neuromodulator circuit dynamics during foraging                                                                                |    1227 |
# | Brain Computer Interface                                                                                                                 |     908 |
# | Ephys Platform                                                                                                                           |     568 |
# | Learning mFISH-V1omFISH                                                                                                                  |     224 |
# | Cell Type LUT                                                                                                                            |     141 |
# | Cell Type Lookup Table                                                                                                                   |     137 |
# | GPP                                                                                                                                      |     105 |
# | OpenScope                                                                                                                                |      95 |
# | Multiplexed Neuromodulation                                                                                                              |      63 |
# | Standalone                                                                                                                               |      16 |
# | Behavior and Motor Control                                                                                                               |      15 |
# | MRI-Guided Electrophysiology                                                                                                             |      14 |
# | NeuropixelsUltra_Psychedelics                                                                                                            |      11 |
# | Thalamus in the middle project 4                                                                                                         |      11 |
# | Discovery-Neuromodulator circuit dynamics during foraging - Subproject 1 Electrophysiological Recordings from NM Neurons During Behavior |       7 |
# | Thalamus in the middle - Project 4 Frontal cortical dynamics and cognitive behaviors                                                     |       3 |
# | Discoovery-Neuromodulation                                                                                                               |       1 |
# | Discovery-Neuromodulation                                                                                                                |       1 |
# | Neuropixels Ultra & Psychedelics                                                                                                         |       1 |
#
#
# ## codeocean-s3datasetsbucket-1u41qdg42ur9: 1,699 records
#
# | project                                                                                                                                  |   count |
# |:-----------------------------------------------------------------------------------------------------------------------------------------|--------:|
# | Behavior Platform                                                                                                                        |    1041 |
# | Discovery-Neuromodulator circuit dynamics during foraging                                                                                |     177 |
# | Cell Type Lookup Table                                                                                                                   |     158 |
# | Learning mFISH-V1omFISH                                                                                                                  |      69 |
# | Dynamic Routing                                                                                                                          |      56 |
# | Ephys Platform                                                                                                                           |      49 |
# | GPP                                                                                                                                      |      44 |
# | OpenScope                                                                                                                                |      29 |
# | Discovery-Neuromodulator circuit dynamics during foraging - Subproject 1 Electrophysiological Recordings from NM Neurons During Behavior |      20 |
# | Cell Type LUT                                                                                                                            |      18 |
# | MRI-Guided Electrophysiology                                                                                                             |      15 |
# | Thalamus in the middle project 4                                                                                                         |      14 |
# | Discoovery-Neuromodulation                                                                                                               |       3 |
# | Thalamus in the middle - Project 4 Frontal cortical dynamics and cognitive behaviors                                                     |       3 |
# | MSMA Platform                                                                                                                            |       2 |
# | MRI-Guided Elecrophysiology                                                                                                              |       1 |
#
#
# ## aind-open-data: 1,163 records
#
# | project                                                                                       |   count |
# |:----------------------------------------------------------------------------------------------|--------:|
# | Thalamus in the middle                                                                        |     349 |
# | MSMA Platform                                                                                 |     193 |
# | CTY Genetic Tools                                                                             |     106 |
# | Cell Type Lookup Table                                                                        |      93 |
# | Ophys Platform - FIP, HSFP and indicator testing                                              |      52 |
# | Genetic Perturbation Platform                                                                 |      51 |
# | Ephys Platform                                                                                |      34 |
# | MRI-Guided Electrophysiology                                                                  |      32 |
# | U19 Thalamus in the Middle                                                                    |      30 |
# | Behavior Platform                                                                             |      27 |
# | Cell Type LUT                                                                                 |      27 |
# | Discovery-Brain Wide Circuit Dynamics                                                         |      24 |
# | MGT                                                                                           |      22 |
# | CTY Program Admin                                                                             |      21 |
# | Dynamic Routing                                                                               |      18 |
# | Discovery-Neuromodulator circuit dynamics during foraging                                     |      12 |
# | - CTY Genetic Tools                                                                           |       7 |
# | 102-01-064-10 - CTY Genetic Tools                                                             |       6 |
# | MRI-Guided Elecrophysiology                                                                   |       6 |
# | Thalamus in the middle - Project 6 Molecular Science Core                                     |       6 |
# | Thalamus in the middle - Project 1 Mesoscale thalamic circuits                                |       5 |
# | AIND Thalamus U19 - Project 2                                                                 |       5 |
# | Brain Computer Interface                                                                      |       5 |
# | AIND Scientific Activities - Molecular and proj                                               |       4 |
# | HIVE                                                                                          |       4 |
# | AIND Scientific Activities - Ephys Platform                                                   |       3 |
# | NP Ultra                                                                                      |       3 |
# | Costa Greene Adrenal                                                                          |       2 |
# | BG AAV Toolbox                                                                                |       2 |
# | AIND Thalamus U19 - Project 4                                                                 |       2 |
# | Ophys platform - FIP, HSFP and indicator testing                                              |       2 |
# | AIND Scientific Activities - Ophys indicator testing                                          |       2 |
# | - CTY GenTools Mouse                                                                          |       2 |
# | Thalamus in the middle - Project 2 Cell-type specific thalamocortical projectome              |       2 |
# | Learning mFISH-V1omFISH                                                                       |       1 |
# | Genetic Perturbation Platform - Subproject 2 Genetic perturbation integration with physiology |       1 |
# | Ephys platform                                                                                |       1 |
# | AIND Thalamus U19 - Project 1                                                                 |       1 |
#
#
# ## aind-ephys-data: 426 records
#
# | project                                                   |   count |
# |:----------------------------------------------------------|--------:|
# | Dynamic Routing                                           |     117 |
# | Discovery-Neuromodulator circuit dynamics during foraging |      95 |
# | Ephys Platform                                            |      94 |
# | Cell Type Lookup Table                                    |      87 |
# | Cell Type LUT                                             |      24 |
# | MRI-Guided Electrophysiology                              |       4 |
# | Thalamus in the middle                                    |       3 |
# | MRI-Guided Elecrophysiology                               |       2 |
#
#
# ## aind-ophys-data: 2 records
#
# | project                  |   count |
# |:-------------------------|--------:|
# | Brain Computer Interface |       2 |
