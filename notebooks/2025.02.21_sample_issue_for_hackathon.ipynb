# %% [markdown]
# ## Imports

# %%
from aind_data_access_api.document_db import MetadataDbClient
import pandas as pd

# Configure pandas to display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Connect to the metadata database

# %%
# Initialize the client
client = MetadataDbClient(
    host="api.allenneuraldynamics.org",
    database="metadata_index",
    collection="data_assets",
)

# %%
query = {"data_description.funding_source.funder": "PGA"}

results = client.retrieve_docdb_records(
    filter_query=query,
    projection={"data_description": 1}
)

len(results)
# Out:
# 81

# %%
# First normalize the main structure
df = pd.json_normalize(results, sep='.', max_level=None)

# Then normalize the funding_source column which contains list of dictionaries
# The 'prefix' parameter is not supported in json_normalize
# We need to rename the columns after normalization instead
funding_df = pd.json_normalize(
    df['data_description.funding_source'].explode().tolist(),
    sep='.'
)
# Add the prefix to column names
funding_df.columns = 'data_description.funding_source.' + funding_df.columns

# Join the funding information back to the main dataframe
df = df.drop('data_description.funding_source', axis=1)
df = pd.concat([df, funding_df], axis=1)

df.sample(10)
# Out:
#                                      _id data_description.creation_date  \
# 59  e24263d6-f792-4ec2-bcb9-71aad0c0a62a                     2023-04-04
# 50  9d24787d-cb1b-40cd-8500-59e6899f75b5                     2023-02-28
# 29  ab2c5322-f2f1-4579-80a3-5c5187873ece                     2023-03-30
# 78  5bd72287-8808-4e41-ba87-039442bd035c                     2023-02-27
# 18  f42aa199-ca24-40ae-a5dd-db5e9029417e                     2023-03-09
# 30  e4d9f654-7cda-48d0-b7b4-b7b78be32ea3                     2023-03-22
# 11  6751f876-3050-4e34-804a-4c70d1ffe504                     2023-03-01
# 20  ecfabdd6-466c-44c0-8912-653cf8f38492                     2023-01-10
# 60  3ecea2ba-ff15-46c5-b168-6e77b3e9bf23                     2023-04-06
# 25  f367e4ee-f1dc-41f2-a6f7-b5a3ce7152a3                     2023-03-30
#
#    data_description.creation_time data_description.data_level  \
# 59                       13:33:00                    raw data
# 50                       19:26:13                    raw data
# 29                21:06:38.037254                derived data
# 78                       14:03:57                    raw data
# 18                       11:58:15                    raw data
# 30                       18:37:30                    raw data
# 11                       13:05:45                    raw data
# 20                       10:55:59                    raw data
# 60                       16:55:38                    raw data
# 25                22:11:58.166466                derived data
#
#                          data_description.describedBy data_description.group  \
# 59  https://raw.githubusercontent.com/AllenNeuralD...                   None
# 50  https://raw.githubusercontent.com/AllenNeuralD...                   None
# 29  https://raw.githubusercontent.com/AllenNeuralD...                   None
# 78  https://raw.githubusercontent.com/AllenNeuralD...                   None
# 18  https://raw.githubusercontent.com/AllenNeuralD...                   None
# 30  https://raw.githubusercontent.com/AllenNeuralD...                   None
# 11  https://raw.githubusercontent.com/AllenNeuralD...                   None
# 20  https://raw.githubusercontent.com/AllenNeuralD...                   None
# 60  https://raw.githubusercontent.com/AllenNeuralD...                   None
# 25  https://raw.githubusercontent.com/AllenNeuralD...                   None
#
#    data_description.institution data_description.license  \
# 59                          NaN                CC-BY-4.0
# 50                         AIBS                CC-BY-4.0
# 29                          NaN                CC-BY-4.0
# 78                         AIBS                CC-BY-4.0
# 18                         AIBS                CC-BY-4.0
# 30                         AIBS                CC-BY-4.0
# 11                         AIBS                CC-BY-4.0
# 20                         AIBS                CC-BY-4.0
# 60                          NaN                CC-BY-4.0
# 25                          NaN                CC-BY-4.0
#
#                             data_description.modality  \
# 59  [{'abbreviation': 'SPIM', 'name': 'Selective p...
# 50                                          SmartSPIM
# 29  [{'abbreviation': 'SPIM', 'name': 'Selective p...
# 78                                          SmartSPIM
# 18                                          SmartSPIM
# 30                                          SmartSPIM
# 11                                          SmartSPIM
# 20                                          SmartSPIM
# 60  [{'abbreviation': 'SPIM', 'name': 'Selective p...
# 25  [{'abbreviation': 'SPIM', 'name': 'Selective p...
#
#                                 data_description.name  \
# 59               SmartSPIM_656702_2023-04-04_13-33-00
# 50               SmartSPIM_654145_2023-02-28_19-26-13
# 29  SmartSPIM_650562_2023-03-27_20-02-47_stitched_...
# 78               SmartSPIM_658357_2023-02-27_14-03-57
# 18               SmartSPIM_660935_2023-03-09_11-58-15
# 30               SmartSPIM_650632_2023-03-22_18-37-30
# 11               SmartSPIM_657999_2023-03-01_13-05-45
# 20               SmartSPIM_645131_2023-01-10_10-55-59
# 60               SmartSPIM_656425_2023-04-06_16-55-38
# 25  SmartSPIM_650554_2023-03-23_18-02-34_stitched_...
#
#    data_description.project_id data_description.project_name  \
# 59               102-01-014-10          - CTY GenTools Mouse
# 50               102-01-014-10                           MGT
# 29                        None                          None
# 78               102-01-014-10                           MGT
# 18               102-01-064-10             CTY Genetic Tools
# 30               102-01-014-10                           MGT
# 11               102-01-014-10                           MGT
# 20                        None                          None
# 60               102-01-014-10          - CTY GenTools Mouse
# 25                        None                          None
#
#    data_description.restrictions data_description.schema_version  \
# 59                          None                           0.4.0
# 50                          None                           0.3.0
# 29                          None                           0.4.0
# 78                          None                           0.3.0
# 18                          None                           0.3.0
# 30                          None                           0.3.2
# 11                          None                           0.3.0
# 20                          None                           0.3.0
# 60                          None                           0.4.0
# 25                          None                           0.4.0
#
#    data_description.subject_id  data_description.data_summary  \
# 59                      656702                            NaN
# 50                      654145                            NaN
# 29                      650562                            NaN
# 78                      658357                            NaN
# 18                      660935                            NaN
# 30                      650632                            NaN
# 11                      657999                            NaN
# 20                      645131                            NaN
# 60                      656425                            NaN
# 25                      650554                            NaN
#
#    data_description.experiment_type      data_description.input_data_name  \
# 59                        SmartSPIM                                   NaN
# 50                              NaN                                   NaN
# 29                        SmartSPIM  SmartSPIM_650562_2023-03-27_20-02-47
# 78                              NaN                                   NaN
# 18                              NaN                                   NaN
# 30                              NaN                                   NaN
# 11                              NaN                                   NaN
# 20                              NaN                                   NaN
# 60                        SmartSPIM                                   NaN
# 25                        SmartSPIM  SmartSPIM_650554_2023-03-23_18-02-34
#
#    data_description.institution.abbreviation  \
# 59                                      AIBS
# 50                                       NaN
# 29                                      AIBS
# 78                                       NaN
# 18                                       NaN
# 30                                       NaN
# 11                                       NaN
# 20                                       NaN
# 60                                      AIBS
# 25                                      AIBS
#
#     data_description.institution.name data_description.investigators  \
# 59  Allen Institute for Brain Science                            NaN
# 50                                NaN                            NaN
# 29  Allen Institute for Brain Science                            NaN
# 78                                NaN                            NaN
# 18                                NaN                            NaN
# 30                                NaN                            NaN
# 11                                NaN                            NaN
# 20                                NaN                            NaN
# 60  Allen Institute for Brain Science                            NaN
# 25  Allen Institute for Brain Science                            NaN
#
#    data_description.related_data  data_description.ror_id  \
# 59                            []                      NaN
# 50                           NaN                      NaN
# 29                            []                      NaN
# 78                           NaN                      NaN
# 18                           NaN                      NaN
# 30                            []                      NaN
# 11                           NaN                      NaN
# 20                           NaN                      NaN
# 60                            []                      NaN
# 25                            []                      NaN
#
#    data_description.funding_source.fundee  \
# 59                                   None
# 50                                   None
# 29                                   None
# 78                                   None
# 18                                   None
# 30                                   None
# 11                                   None
# 20                                   None
# 60                                   None
# 25                                   None
#
#    data_description.funding_source.funder  \
# 59                                    PGA
# 50                                    PGA
# 29                                    PGA
# 78                                    PGA
# 18                                    PGA
# 30                                    PGA
# 11                                    PGA
# 20                                    PGA
# 60                                    PGA
# 25                                    PGA
#
#    data_description.funding_source.grant_number
# 59                                         None
# 50                                         None
# 29                                         None
# 78                                         None
# 18                                         None
# 30                                         None
# 11                                         None
# 20                                         None
# 60                                         None
# 25                                         None

# %%
print(df['data_description.funding_source.funder'].unique())
# Out:
# ['PGA']

# %%
results[0]['data_description']['funding_source']
# Out:
# [{'fundee': None, 'funder': 'PGA', 'grant_number': None}]

# %%
from aind_data_schema_models.organizations import Organization
new_funder = Organization.AI.model_dump()
new_funder
# Out:
# {'name': 'Allen Institute',
#  'abbreviation': 'AI',
#  'registry': {'name': 'Research Organization Registry', 'abbreviation': 'ROR'},
#  'registry_identifier': '03cpe7c52'}
