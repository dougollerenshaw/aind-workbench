# %%
from backfill_specimen_procedures import (
    get_specimen_procedures_from_spreadsheet, 
    backfill_specimen_procedures_for_subject,
    test_specimen_procedures_match,
)

# %%
specimen_procedures = get_specimen_procedures_from_spreadsheet("791054")
specimen_procedures
# Out:
# [{'procedure_type': 'Delipidation',
#   'procedure_name': 'LifeCanvas Active Whole Mouse Brain Delipidation (UNPUBLISHED)',
#   'specimen_id': '791054',
#   'start_date': '2025-06-30',
#   'end_date': '2025-07-03',
#   'experimenter_full_name': 'Unknown',
#   'protocol_id': None,
#   'reagents': [{'name': 'DB-500',
#     'source': None,
#     'rrid': None,
#     'lot_number': 'bu29',
#     'expiration_date': None},
#    {'name': 'SH-ON',
#     'source': None,
#     'rrid': None,
#     'lot_number': 'ex59',
#     'expiration_date': None}],
#   'hcr_series': None,
#   'antibodies': None,
#   'sectioning': None,
#   'notes': None},
#  {'procedure_type': 'Delipidation',
#   'procedure_name': 'LifeCanvas Active Whole Mouse Brain Delipidation (UNPUBLISHED)',
#   'specimen_id': '791054',
#   'start_date': '2025-07-03',
#   'end_date': '2025-07-04',
#   'experimenter_full_name': 'Unknown',
#   'protocol_id': None,
#   'reagents': [{'name': 'SH-ON',
#     'source': None,
#     'rrid': None,
# ...

# %%
specimen_procedures = get_specimen_procedures_from_spreadsheet("716946")
specimen_procedures
# Out:
# [{'procedure_type': 'Delipidation',
#   'procedure_name': 'LifeCanvas Active Whole Mouse Brain Delipidation (UNPUBLISHED)',
#   'specimen_id': '716946',
#   'start_date': '2024-04-19',
#   'end_date': '2024-04-22',
#   'experimenter_full_name': 'Unknown',
#   'protocol_id': None,
#   'reagents': [{'name': 'DB-500',
#     'source': None,
#     'rrid': None,
#     'lot_number': 'bu19',
#     'expiration_date': None},
#    {'name': 'SH-ON',
#     'source': None,
#     'rrid': None,
#     'lot_number': 'ex35',
#     'expiration_date': None}],
#   'hcr_series': None,
#   'antibodies': None,
#   'sectioning': None,
#   'notes': None},
#  {'procedure_type': 'Delipidation',
#   'procedure_name': 'LifeCanvas Active Whole Mouse Brain Delipidation (UNPUBLISHED)',
#   'specimen_id': '716946',
#   'start_date': '2024-04-22',
#   'end_date': '2024-04-23',
#   'experimenter_full_name': 'Unknown',
#   'protocol_id': None,
#   'reagents': [{'name': 'SH-ON',
#     'source': None,
#     'rrid': None,
# ...

# %%
# Test with the subject you provided
test_result = test_specimen_procedures_match("791054")
# Out:
# Testing specimen procedures match for subject 791054
# ...
# ✓ Successfully generated procedures from spreadsheet for 791054
# ✗ No SmartSPIM assets found for subject 791054

# %%
specimen_procedures = get_specimen_procedures_from_spreadsheet("716946")
specimen_procedures
# Out:
# [{'procedure_type': 'Delipidation',
#   'procedure_name': 'LifeCanvas Active Whole Mouse Brain Delipidation (UNPUBLISHED)',
#   'specimen_id': '716946',
#   'start_date': '2024-04-19',
#   'end_date': '2024-04-22',
#   'experimenter_full_name': 'Unknown',
#   'protocol_id': None,
#   'reagents': [{'name': 'DB-500',
#     'source': None,
#     'rrid': None,
#     'lot_number': 'bu19',
#     'expiration_date': None},
#    {'name': 'SH-ON',
#     'source': None,
#     'rrid': None,
#     'lot_number': 'ex35',
#     'expiration_date': None}],
#   'hcr_series': None,
#   'antibodies': None,
#   'sectioning': None,
#   'notes': None},
#  {'procedure_type': 'Delipidation',
#   'procedure_name': 'LifeCanvas Active Whole Mouse Brain Delipidation (UNPUBLISHED)',
#   'specimen_id': '716946',
#   'start_date': '2024-04-22',
#   'end_date': '2024-04-23',
#   'experimenter_full_name': 'Unknown',
#   'protocol_id': None,
#   'reagents': [{'name': 'SH-ON',
#     'source': None,
#     'rrid': None,
# ...
