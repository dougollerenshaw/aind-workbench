# %%
from backfill_specimen_procedures import (
    get_specimen_procedures_from_spreadsheet, 
    test_specimen_procedures_match,
)

# %%
specimen_procedures = get_specimen_procedures_from_spreadsheet("791054")
specimen_procedures
# Out:
# [{'procedure_type': 'Fixation',
#   'procedure_name': 'SHIELD OFF',
#   'specimen_id': '791054',
#   'start_date': '2025-06-30',
#   'end_date': '2025-07-03',
#   'experimenter_full_name': 'Unknown',
#   'protocol_id': None,
#   'reagents': [],
#   'notes': '7/4/25 - 7/7/25 1xpbs in 4c',
#   'batch_info': {'batch_number': '149',
#    'date_range_tab': 'Additional batch info'}},
#  {'procedure_type': 'Fixation',
#   'procedure_name': 'SHIELD ON',
#   'specimen_id': '791054',
#   'start_date': '2025-07-03',
#   'end_date': '2025-07-04',
#   'experimenter_full_name': 'Unknown',
#   'protocol_id': None,
#   'reagents': [],
#   'notes': '7/4/25 - 7/7/25 1xpbs in 4c',
#   'batch_info': {'batch_number': '149',
#    'date_range_tab': 'Additional batch info'}},
#  {'procedure_type': 'Delipidation',
#   'procedure_name': 'Passive Delipidation',
#   'specimen_id': '791054',
#   'start_date': '2025-07-07',
#   'end_date': '2025-07-08',
#   'experimenter_full_name': 'Unknown',
#   'protocol_id': None,
#   'reagents': [],
#   'notes': None,
#   'batch_info': {'batch_number': '149',
#    'date_range_tab': 'Additional batch info'}},
#  {'procedure_type': 'Delipidation',
#   'procedure_name': 'Active Delipidation',
#   'specimen_id': '791054',
#   'start_date': '2025-07-08',
#   'end_date': '2025-07-10',
#   'experimenter_full_name': 'Unknown',
#   'protocol_id': None,
#   'reagents': [],
#   'notes': None,
#   'batch_info': {'batch_number': '149',
#    'date_range_tab': 'Additional batch info'}},
#  {'procedure_type': 'Refractive index matching',
#   'procedure_name': 'EasyIndex',
#   'specimen_id': '791054',
#   'start_date': '2025-07-09',
#   'end_date': '2025-07-12',
#   'experimenter_full_name': 'Unknown',
#   'protocol_id': ['dx.doi.org/10.17504/protocols.io.kxygx965kg8j/v1'],
#   'reagents': [],
#   'notes': None,
#   'batch_info': {'batch_number': '149',
#    'date_range_tab': 'Additional batch info'}}]

# %%
# Out:
# Finding AIND sessions in spreadsheet with different specimen procedures status...
# Found 2733 AIND sessions in spreadsheet
# Specimen procedures status breakdown:
# has_specimen_procedures
# True     1630
# False    1103
# Name: count, dtype: int64
#
# Sessions WITH specimen procedures: 1630
# Sessions WITHOUT specimen procedures: 1103
#
# ================================================================================
# SELECTED EXAMPLES FOR YOUR PRESENTATION:
# ================================================================================
#
# 1. SUBJECT 654092 - WITH specimen procedures:
#    Asset: SmartSPIM_654092_2023-01-26_10-45-12_stitched_2023-02-02_21-58-54
#    Collection Date: 2023-01-26
#
# 2. SUBJECT 652504 - WITHOUT specimen procedures:
#    Asset: SmartSPIM_652504_2023-01-07_13-51-57_stitched_2023-02-09_17-18-01
#    Collection Date: 2023-01-07
#
# ================================================================================
# FULL PROCEDURES RECORDS FOR YOUR SLIDES:
# ================================================================================
#
# 1. FULL PROCEDURES RECORD FOR SUBJECT 654092 (WITH specimen procedures):
# ------------------------------------------------------------
# Asset: SmartSPIM_654092_2023-01-26_10-45-12
# Subject ID: 654092
# Specimen procedures count: 6
#
# Full procedures JSON (copy this for your slides):
# {
#   "describedBy": "https://raw.githubusercontent.com/AllenNeuralDynamics/aind-data-schema/main/src/aind_data_schema/core/procedures.py",
#   "schema_version": "0.11.2",
#   "subject_id": "654092",
#   "subject_procedures": [
#     {
#       "procedure_type": "Surgery",
#       "start_date": "2022-12-09",
#       "experimenter_full_name": "30509",
#       "iacuc_protocol": null,
#       "animal_weight_prior": null,
#       "animal_weight_post": null,
#       "weight_unit": "gram",
#       "anaesthesia": null,
#       "workstation_id": null,
#       "procedures": [
#         {
#           "procedure_type": "Perfusion",
#           "protocol_id": "dx.doi.org/10.17504/protocols.io.bg5vjy66",
#           "output_specimen_ids": [
#             "654092"
#           ]
#         }
#       ],
#       "notes": null
#     },
#     {
#       "procedure_type": "Surgery",
#       "start_date": "2022-11-11",
#       "experimenter_full_name": "NSB-5756",
#       "iacuc_protocol": null,
#       "animal_weight_prior": "14.0",
#       "animal_weight_post": "14.0",
#       "weight_unit": "gram",
#       "anaesthesia": null,
#       "workstation_id": "SWS 3",
#       "procedures": [
#         {
#           "injection_materials": [
#             {
#               "material_type": "Virus",
#               "name": "SL1-hSyn-Cre",
#               "tars_identifiers": {
#                 "virus_tars_id": null,
#                 "plasmid_tars_alias": null,
#                 "prep_lot_number": "190102",
#                 "prep_date": null,
#                 "prep_type": null,
#                 "prep_protocol": null
#               },
#               "addgene_id": null,
#               "titer": 28700000000003,
#               "titer_unit": "gc/mL"
#             },
#             {
#               "material_type": "Virus",
#               "name": "AAV1-CAG-H2B-mTurquoise2-WPRE",
#               "tars_identifiers": {
#                 "virus_tars_id": null,
#                 "plasmid_tars_alias": null,
#                 "prep_lot_number": "VT4357g",
#                 "prep_date": null,
#                 "prep_type": null,
#                 "prep_protocol": null
#               },
#               "addgene_id": null,
#               "titer": 5040000000003,
#               "titer_unit": "gc/mL"
#             }
#           ],
#           "recovery_time": "10.0",
#           "recovery_time_unit": "minute",
#           "injection_duration": null,
#           "injection_duration_unit": "minute",
#           "instrument_id": "NJ#3",
#           "protocol_id": "dx.doi.org/10.17504/protocols.io.bgpujvnw",
#           "injection_coordinate_ml": "-0.35",
#           "injection_coordinate_ap": "2.2",
#           "injection_coordinate_depth": [
#             "2.1"
#           ],
#           "injection_coordinate_unit": "millimeter",
#           "injection_coordinate_reference": null,
#           "bregma_to_lambda_distance": null,
#           "bregma_to_lambda_unit": "millimeter",
#           "injection_angle": "0",
#           "injection_angle_unit": "degrees",
#           "targeted_structure": "mPFC",
#           "injection_hemisphere": "Left",
#           "procedure_type": "Nanoject injection",
#           "injection_volume": [
#             "200"
#           ],
#           "injection_volume_unit": "nanoliter"
#         },
#         {
#           "injection_materials": [
#             {
#               "material_type": "Virus",
#               "name": "AAV-Syn-DIO-TVA66T-dTomato-CVS N2cG",
#               "tars_identifiers": {
#                 "virus_tars_id": null,
#                 "plasmid_tars_alias": null,
#                 "prep_lot_number": "VT2532g",
#                 "prep_date": null,
#                 "prep_type": null,
#                 "prep_protocol": null
#               },
#               "addgene_id": null,
#               "titer": null,
#               "titer_unit": "gc/mL"
#             }
#           ],
#           "recovery_time": null,
#           "recovery_time_unit": "minute",
#           "injection_duration": null,
#           "injection_duration_unit": "minute",
#           "instrument_id": null,
#           "protocol_id": "dx.doi.org/10.17504/protocols.io.bgpujvnw",
#           "injection_coordinate_ml": "-2.9",
#           "injection_coordinate_ap": "-0.6",
#           "injection_coordinate_depth": [
#             "3.6"
#           ],
#           "injection_coordinate_unit": "millimeter",
#           "injection_coordinate_reference": null,
#           "bregma_to_lambda_distance": null,
#           "bregma_to_lambda_unit": "millimeter",
#           "injection_angle": "30",
#           "injection_angle_unit": "degrees",
#           "targeted_structure": "VM",
#           "injection_hemisphere": "Left",
#           "procedure_type": "Nanoject injection",
#           "injection_volume": [
#             "200"
#           ],
#           "injection_volume_unit": "nanoliter"
#         }
#       ],
#       "notes": null
#     },
#     {
#       "procedure_type": "Surgery",
#       "start_date": "2022-11-29",
#       "experimenter_full_name": "NSB-5756",
#       "iacuc_protocol": null,
#       "animal_weight_prior": "20.9",
#       "animal_weight_post": "20.9",
#       "weight_unit": "gram",
#       "anaesthesia": null,
#       "workstation_id": "SWS 1",
#       "procedures": [
#         {
#           "injection_materials": [
#             {
#               "material_type": "Virus",
#               "name": "EnvA CVS-N2C-histone-GFP",
#               "tars_identifiers": {
#                 "virus_tars_id": null,
#                 "plasmid_tars_alias": null,
#                 "prep_lot_number": "V7",
#                 "prep_date": null,
#                 "prep_type": null,
#                 "prep_protocol": null
#               },
#               "addgene_id": null,
#               "titer": null,
#               "titer_unit": "gc/mL"
#             }
#           ],
#           "recovery_time": "15.0",
#           "recovery_time_unit": "minute",
#           "injection_duration": null,
#           "injection_duration_unit": "minute",
#           "instrument_id": null,
#           "protocol_id": "dx.doi.org/10.17504/protocols.io.bgpujvnw",
#           "injection_coordinate_ml": "-2.9",
#           "injection_coordinate_ap": "-0.6",
#           "injection_coordinate_depth": [
#             "3.6"
#           ],
#           "injection_coordinate_unit": "millimeter",
#           "injection_coordinate_reference": null,
#           "bregma_to_lambda_distance": null,
#           "bregma_to_lambda_unit": "millimeter",
#           "injection_angle": "30",
#           "injection_angle_unit": "degrees",
#           "targeted_structure": "VM",
#           "injection_hemisphere": "Left",
#           "procedure_type": "Nanoject injection",
#           "injection_volume": [
#             "200"
#           ],
#           "injection_volume_unit": "nanoliter"
#         }
#       ],
#       "notes": null
#     }
#   ],
#   "specimen_procedures": [
#     {
#       "procedure_type": "Fixation",
#       "procedure_name": "SHIELD OFF",
#       "specimen_id": "654092",
#       "start_date": "2023-01-09",
#       "end_date": "2023-01-11",
#       "experimenter_full_name": "DT",
#       "protocol_id": "none",
#       "reagents": [
#         {
#           "name": "SHIELD Epoxy",
#           "source": "LiveCanvas Technologies",
#           "rrid": null,
#           "lot_number": "unknown",
#           "expiration_date": null
#         },
#         {
#           "name": "SHIELD Buffer",
#           "source": "LiveCanvas Technologies",
#           "rrid": null,
#           "lot_number": "unknown",
#           "expiration_date": null
#         }
#       ],
#       "hcr_series": null,
#       "immunolabeling": null,
#       "notes": "None"
#     },
#     {
#       "procedure_type": "Fixation",
#       "procedure_name": "SHIELD ON",
#       "specimen_id": "654092",
#       "start_date": "2023-01-11",
#       "end_date": "2023-01-12",
#       "experimenter_full_name": "DT",
#       "protocol_id": "none",
#       "reagents": [
#         {
#           "name": "SHIELD ON",
#           "source": "LiveCanvas Technologies",
#           "rrid": null,
#           "lot_number": "unknown",
#           "expiration_date": null
#         }
#       ],
#       "hcr_series": null,
#       "immunolabeling": null,
#       "notes": "None"
#     },
#     {
#       "procedure_type": "Delipidation",
#       "procedure_name": "24h Delipidation",
#       "specimen_id": "654092",
#       "start_date": "2023-01-13",
#       "end_date": "2023-01-14",
#       "experimenter_full_name": "DT",
#       "protocol_id": "none",
#       "reagents": [
#         {
#           "name": "Delipidation Buffer",
#           "source": "LiveCanvas Technologies",
#           "rrid": null,
#           "lot_number": "unknown",
#           "expiration_date": null
#         }
#       ],
#       "hcr_series": null,
#       "immunolabeling": null,
#       "notes": "None"
#     },
#     {
#       "procedure_type": "Delipidation",
#       "procedure_name": "Active Delipidation",
#       "specimen_id": "654092",
#       "start_date": "2023-01-15",
#       "end_date": "2023-01-17",
#       "experimenter_full_name": "DT",
#       "protocol_id": "none",
#       "reagents": [
#         {
#           "name": "Conduction Buffer",
#           "source": "LiveCanvas Technologies",
#           "rrid": null,
#           "lot_number": "unknown",
#           "expiration_date": null
#         }
#       ],
#       "hcr_series": null,
#       "immunolabeling": null,
#       "notes": "None"
#     },
#     {
#       "procedure_type": "Refractive index matching",
#       "procedure_name": "50% EasyIndex",
#       "specimen_id": "654092",
#       "start_date": "2023-01-17",
#       "end_date": "2023-01-18",
#       "experimenter_full_name": "DT",
#       "protocol_id": "none",
#       "reagents": [
#         {
#           "name": "EasyIndex",
#           "source": "LiveCanvas Technologies",
#           "rrid": null,
#           "lot_number": "unknown",
#           "expiration_date": null
#         }
#       ],
#       "hcr_series": null,
#       "immunolabeling": null,
#       "notes": "degassed on both steps"
#     },
#     {
#       "procedure_type": "Refractive index matching",
#       "procedure_name": "100% EasyIndex",
#       "specimen_id": "654092",
#       "start_date": "2023-01-18",
#       "end_date": "2023-01-19",
#       "experimenter_full_name": "DT",
#       "protocol_id": "none",
#       "reagents": [
#         {
#           "name": "EasyIndex",
#           "source": "LiveCanvas Technologies",
#           "rrid": null,
#           "lot_number": "unknown",
#           "expiration_date": null
#         }
#       ],
#       "hcr_series": null,
#       "immunolabeling": null,
#       "notes": "degassed on both steps"
#     }
#   ],
#   "notes": null
# }
#
#
# 2. FULL PROCEDURES RECORD FOR SUBJECT 652504 (WITHOUT specimen procedures):
# ------------------------------------------------------------
# Asset: SmartSPIM_652504_2023-01-07_13-51-57_stitched_2023-02-09_17-18-01
# Subject ID: 652504
# Specimen procedures count: 0
#
# Full procedures JSON (copy this for your slides):
# {
#   "describedBy": "https://raw.githubusercontent.com/AllenNeuralDynamics/aind-data-schema/main/src/aind_data_schema/core/procedures.py",
#   "schema_version": "0.11.2",
#   "subject_id": "652504",
#   "subject_procedures": [
#     {
#       "procedure_type": "Surgery",
#       "start_date": "2022-11-28",
#       "experimenter_full_name": "30509",
#       "iacuc_protocol": null,
#       "animal_weight_prior": null,
#       "animal_weight_post": null,
#       "weight_unit": "gram",
#       "anaesthesia": null,
#       "workstation_id": null,
#       "procedures": [
#         {
#           "procedure_type": "Perfusion",
#           "protocol_id": "dx.doi.org/10.17504/protocols.io.bg5vjy66",
#           "output_specimen_ids": [
#             "652504"
#           ]
#         }
#       ],
#       "notes": null
#     },
#     {
#       "procedure_type": "Surgery",
#       "start_date": "2022-10-28",
#       "experimenter_full_name": "NSB-187",
#       "iacuc_protocol": null,
#       "animal_weight_prior": "15.3",
#       "animal_weight_post": "15.3",
#       "weight_unit": "gram",
#       "anaesthesia": null,
#       "workstation_id": "SWS 4",
#       "procedures": [
#         {
#           "injection_materials": [
#             {
#               "material_type": "Virus",
#               "name": "SL1-hSyn-Cre",
#               "tars_identifiers": {
#                 "virus_tars_id": null,
#                 "plasmid_tars_alias": null,
#                 "prep_lot_number": "190102",
#                 "prep_date": null,
#                 "prep_type": null,
#                 "prep_protocol": null
#               },
#               "addgene_id": null,
#               "titer": 28700000000000,
#               "titer_unit": "gc/mL"
#             },
#             {
#               "material_type": "Virus",
#               "name": "AAV1-CAG-H2B-mTurquoise2-WPRE",
#               "tars_identifiers": {
#                 "virus_tars_id": null,
#                 "plasmid_tars_alias": null,
#                 "prep_lot_number": "VT4357g",
#                 "prep_date": null,
#                 "prep_type": null,
#                 "prep_protocol": null
#               },
#               "addgene_id": null,
#               "titer": 5040000000000,
#               "titer_unit": "gc/mL"
#             }
#           ],
#           "recovery_time": "10.0",
#           "recovery_time_unit": "minute",
#           "injection_duration": null,
#           "injection_duration_unit": "minute",
#           "instrument_id": "NJ#4",
#           "protocol_id": "dx.doi.org/10.17504/protocols.io.bgpujvnw",
#           "injection_coordinate_ml": "0.35",
#           "injection_coordinate_ap": "2.2",
#           "injection_coordinate_depth": [
#             "2.1"
#           ],
#           "injection_coordinate_unit": "millimeter",
#           "injection_coordinate_reference": null,
#           "bregma_to_lambda_distance": null,
#           "bregma_to_lambda_unit": "millimeter",
#           "injection_angle": "0",
#           "injection_angle_unit": "degrees",
#           "targeted_structure": "mPFC",
#           "injection_hemisphere": "Right",
#           "procedure_type": "Nanoject injection",
#           "injection_volume": [
#             "200"
#           ],
#           "injection_volume_unit": "nanoliter"
#         },
#         {
#           "injection_materials": [
#             {
#               "material_type": "Virus",
#               "name": "AAV-Syn-DIO-TVA66T-dTomato-CVS N2cG",
#               "tars_identifiers": {
#                 "virus_tars_id": null,
#                 "plasmid_tars_alias": null,
#                 "prep_lot_number": "VT2532g",
#                 "prep_date": null,
#                 "prep_type": null,
#                 "prep_protocol": null
#               },
#               "addgene_id": null,
#               "titer": null,
#               "titer_unit": "gc/mL"
#             }
#           ],
#           "recovery_time": null,
#           "recovery_time_unit": "minute",
#           "injection_duration": null,
#           "injection_duration_unit": "minute",
#           "instrument_id": null,
#           "protocol_id": "dx.doi.org/10.17504/protocols.io.bgpujvnw",
#           "injection_coordinate_ml": "2.9",
#           "injection_coordinate_ap": "-0.6",
#           "injection_coordinate_depth": [
#             "3.6"
#           ],
#           "injection_coordinate_unit": "millimeter",
#           "injection_coordinate_reference": null,
#           "bregma_to_lambda_distance": null,
#           "bregma_to_lambda_unit": "millimeter",
#           "injection_angle": "30",
#           "injection_angle_unit": "degrees",
#           "targeted_structure": "VM",
#           "injection_hemisphere": "Left",
#           "procedure_type": "Nanoject injection",
#           "injection_volume": [
#             "200"
#           ],
#           "injection_volume_unit": "nanoliter"
#         }
#       ],
#       "notes": null
#     },
#     {
#       "procedure_type": "Surgery",
#       "start_date": "2022-11-18",
#       "experimenter_full_name": "NSB-5756",
#       "iacuc_protocol": null,
#       "animal_weight_prior": "20.9",
#       "animal_weight_post": "20.9",
#       "weight_unit": "gram",
#       "anaesthesia": null,
#       "workstation_id": "SWS 2",
#       "procedures": [
#         {
#           "injection_materials": [
#             {
#               "material_type": "Virus",
#               "name": "EnvA CVS-N2C-histone-GFP",
#               "tars_identifiers": {
#                 "virus_tars_id": null,
#                 "plasmid_tars_alias": null,
#                 "prep_lot_number": "V7",
#                 "prep_date": null,
#                 "prep_type": null,
#                 "prep_protocol": null
#               },
#               "addgene_id": null,
#               "titer": null,
#               "titer_unit": "gc/mL"
#             }
#           ],
#           "recovery_time": null,
#           "recovery_time_unit": "minute",
#           "injection_duration": null,
#           "injection_duration_unit": "minute",
#           "instrument_id": "NJ#2",
#           "protocol_id": "dx.doi.org/10.17504/protocols.io.bgpujvnw",
#           "injection_coordinate_ml": "2.9",
#           "injection_coordinate_ap": "-0.6",
#           "injection_coordinate_depth": [
#             "3.6"
#           ],
#           "injection_coordinate_unit": "millimeter",
#           "injection_coordinate_reference": null,
#           "bregma_to_lambda_distance": null,
#           "bregma_to_lambda_unit": "millimeter",
#           "injection_angle": "30",
#           "injection_angle_unit": "degrees",
#           "targeted_structure": "VM",
#           "injection_hemisphere": "Right",
#           "procedure_type": "Nanoject injection",
#           "injection_volume": [
#             "200"
#           ],
#           "injection_volume_unit": "nanoliter"
#         }
#       ],
#       "notes": null
#     }
#   ],
#   "specimen_procedures": [],
#   "notes": null
# }
